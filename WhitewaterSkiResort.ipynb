# %%
import matplotlib.pyplot as plt

from forecast import forecast

# %matplotlib inline

# %%
LAT_LON  = (49.44, 360-117.15)
FEATURES = {'Glory Base': 1400,
            'Glory Top' : 2000,
            'Whitewater Base': 1620}

wwfcst = forecast(LAT_LON, FEATURES, 'Whitewater Ski Resort')
# Out:
# Loading Forecast Data for Whitewater Ski Resort ...
# This may take several minutes ...
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# ...

# %%
fig, ax = wwfcst.temperature_plot()

plt.show()

# %%
fig, ax = wwfcst.humidity_plot()

plt.show()

# %%
fig, ax = wwfcst.wind_plot()

plt.show()

# %%
fig, ax = wwfcst.snow_plot()

plt.show()
