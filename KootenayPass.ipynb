# %%
import matplotlib.pyplot as plt

from forecast import forecast

# %matplotlib inline

# %%
LAT_LON  = (49.06, 360-117.04)
FEATURES = {'Bridal Lake (Parking)': 1775,
            'Cornice Ridge' : 2125,
            'Ripple Mountain': 2325}

kpfcst = forecast(LAT_LON, FEATURES, 'Kootenay Pass')
# Out:
# Loading Forecast Data for Kootenay Pass ...
# This may take several minutes ...
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# /Users/benjaminghertner/miniforge3/envs/envPython3.10/lib/python3.10/site-packages/herbie/core.py:1280: UserWarning: Will not remove GRIB file because it previously existed.
#   warnings.warn("Will not remove GRIB file because it previously existed.")
# ...

# %%
fig, ax = kpfcst.temperature_plot()

plt.show()

# %%
fig, ax = kpfcst.humidity_plot()

plt.show()

# %%
fig, ax = kpfcst.wind_plot()

plt.show()

# %%
fig, ax = kpfcst.snow_plot()

plt.show()
